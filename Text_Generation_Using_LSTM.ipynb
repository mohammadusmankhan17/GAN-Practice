# %%
# !pip install tensorflow==1.15

# %%
# !pip install keras==2.0.8

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.0.8'

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:58: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:442: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3543: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2759: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:625: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:899: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:886: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2294: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:158: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:333: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:341: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 200278/200278 [==============================] - 150s - loss: 1.9747
# --- Generating with seed: " light,"
# and can no longer assign any limit, restraint, or f"
# ------ temperature: 0.2
#  light,"
# and can no longer assign any limit, restraint, or from the man in the presention of the and the all and the and the and so the spepted and and the sense of the sense of the the one and the and the one and the all the the sone the one and the and the and and the condured the the presenting the mankind of the world and the sense of the and the sense and the spirit of the and the one in the and and the one and the and the and the the and the one all
# ------ temperature: 0.5
# and and the one and the and the and the the and the one all the condure and sonestement presention of the superficed and condisterents of such all sen the and reins the
# enery and thene is some the self-callations of the represence of feal presentions the and as the grout sander indures the day of the one and the mankind present to his the the lones the supertions of supersting the aspection of the "muse but the world the religious, who the and sone the rea
# ------ temperature: 1.0
#  "muse but the world the religious, who the and sone the reaking ummore a morales; they good, more poin,.  the present to sen in the leadubevount. indsorefiniant--like
# and levers,
# implect of the pressming, has worled
# disputactedial religrint, obe endsqory of "munctatient. for of litates. "hord condepur nener
# hide perfteness of grod" brourt therenveroances--their
# the ideled nature of prosule exsences, that to
# concuaties their us a "mandatis i longen one the
# ------ temperature: 1.2
# es, that to
# concuaties their us a "mandatis i longen one theirsatono losces."
#
#
#
#
#
# =
# =kbub6zenely (ang indicexesadresombally--loghing esyrmitusting, meny itsitk; looks moreuny to he elreme, there its lagerfainitym--act a thauganrsing--he anastecttaply that them, trutg, onessagyenucceal and a stoltmel andis.k
#
# ke man-he the uppiase out, and difund, lenevery
#
# hisedwhysh
# of it, ind,g
# in herectrriby conrecrated to valuating, has in the inylusat acke, the all
# .
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 147s - loss: 1.6287
# --- Generating with seed: "s down hard enough to obliterate the lines
# imprinted by ages"
# ------ temperature: 0.2
# s down hard enough to obliterate the lines
# imprinted by ages and the same the sense of the contradict of the the sense and the far the men of the has the man with the man the man with the sense of the man with the schorage the
# greater and the sense of the strength the man with the man the greater the man with the constitute and the presence of the presence of the conditions of the men of the man who has the presence of the morality of the moral and the sen
# ------ temperature: 0.5
# ho has the presence of the morality of the moral and the sense of the precicce of such and wish something and the man the ascentance of the man conscience of the promome in the family the bad the strengther, as distrust the problems of the far in a something the reasing of the sunficed--the ancessity and and in every arind the sames in canic or one has nothing conditions and more intentions and so one like and something that the men is desirable the spirit
# ------ temperature: 1.0
#  one like and something that the men is desirable the spirit haovether
# love, appecafnes.
#
#
#
# clultality strict to the ance hemvenoul--should decience,
# thearing no musuntly that posises lek to
# akpact of died, and lipe, and that the
# occero sees. "virit existics, provance a regarden resplitions"; it originism," from he lofm to atsincate the
# frien repeachest vicity deviltless: thinks, and one has
# nevenchenoure inclines a
# than how only periods arte itself must b
# ------ temperature: 1.2
# chenoure inclines a
# than how only periods arte itself must bhthkous, an arminess,
# and punwirds agnousp! and the befies," to community
# and retionenness.s
# like ormy is
# nortothers, they
# hough it is germans, orgaries are, here dulcked and
# roust tran,
# formuloped.
# foul actagions,city
# conarst.
# -newed, extrin not misurdent
# and falseadenessingd and pryqueest aving seebly lab, hen dimply "ori-"be nayrigbling beguthoundon
# onx the
# stulnetionally
# morality tewek gerthin
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 148s - loss: 1.5451
# --- Generating with seed: "thing privileged and
# autocratic--likewise a second and more "
# ------ temperature: 0.2
# thing privileged and
# autocratic--likewise a second and more the most philosophers and the sense of the sourselves and spirit to the sense of the most compore the contrades of the same to the most be the most german preciself--and something the compore of the commanding the compleared in the sense of the present the most complence of the sourselves and the most compore the present the compained the sense of the most for the great spirit of the complence of
# ------ temperature: 0.5
#  sense of the most for the great spirit of the complence of more to be has at the precisely by the curing the world for the sourselves with the despect to the same to sense to the man of himself in the same to self-power that it is the conception and that it is a present the great despection has the most for explebler with it is a chervent these is with the power a sour ades and for the good of the will the compleasing the contradectic spon success of many
# ------ temperature: 1.0
# e will the compleasing the contradectic spon success of many go
# dreltarn, no others light.--physious above love
# ifftroy is by theirgowanly to cheirs, theom to elses, all the dectimated), and reverent, spirits
# stifuint is now times
# world supficuly, all the bodians (more movent
# the lofic and long to orcesse, one felucles with
# a prehhautoanmthy in feelinged philosopheissood the semman to immangoulfience is to
# gubytlofifiction of
# dis." harding for woncleome is
# ------ temperature: 1.2
# nce is to
# gubytlofifiction of
# dis." harding for woncleome isufut this mentt,ry and
# prefience that chrivas
# hor to mongurgopet for their sour-proougss a commandor has to self-angwordsfar of chysicachs whice reenes! from
# man,
# ind
# accorning indirifihety of concusions,anorwhe must view
# unhows imporenetysts--"may yut to
# claking for their
# modest
# explabsurivation." muponeut judem, alilogmes, and,
# god,
# mower, sympenation: free greaty,
# harses.
#
#
# ;
# douthoral thind s
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 148s - loss: 1.5004
# --- Generating with seed: "--my truths.
#
# 232. woman wishes to be independent, and there"
# ------ temperature: 0.2
# --my truths.
#
# 232. woman wishes to be independent, and there is a present and different of the most and in the person of the present to the strange is the sense and the believe the man and the different to the person to the command and in the delight to the strength of the soul is the sense to the present the person to the philosophy of the modern and the man to the properitic and the propers and different and so the sours to the person of the contradictin
# ------ temperature: 0.5
# different and so the sours to the person of the contradicting is and contitions and and the most fars to the interpositions also the sour conceacses and the german of one finds men as the german of the assument to the sensation of its for the interpation of his perhaps men are to as an and interpreligical person that the actitic of the the german presently for the spirit of present as the feated to really that the commandly and the instincts of a good and
# ------ temperature: 1.0
# o really that the commandly and the instincts of a good and also refuse, to trxingle, teniest
# wild of grest surtifice is tover self in usility of good afffice gresificalk of matyashing
# in
# omispares in the flavour that the herpity of
# portibility pre:in forete," a receod to picuseatres: who strength, successful
# housale; indeed, has once sufficienter the from eccording to utilitys, than to be nosedful ous sense, like it would
# what
# indigence the promisists, bu
# ------ temperature: 1.2
# l ous sense, like it would
# what
# indigence the promisists, but orty.
#
# vionstatures,
# by typons perhaps preselve, who
# "midor, which age astivite his vartaises 2actory
# it himself's bestimrle
# moderne? as a prifices notivewby to
# unconspiestific
# loves beyly, dar farsfulne-
# woman the womanmictericies? ails, the imseln, "genesh, there.s
#
#
# ?7
# herars, insuccess sanutee to
# recentable operlaw, illlesme and
# which
# effen). as the orseitenious perkerd tapsem as eseuratily:
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 148s - loss: 1.4713
# --- Generating with seed: "should be, he will meet with suitable auxiliaries who will s"
# ------ temperature: 0.2
# should be, he will meet with suitable auxiliaries who will seems there and sense and sense of the concerning to the comparing and self-be one of the servants of the most self-and self-in the concerning to the germands of which has attained and destrustice and self-refined and self-and sense of the sense of the sense of the commanding of the sense and comparing to the servant of the sense of the concerning the concerning the sense of the superiority of the
# ------ temperature: 0.5
# ncerning the concerning the sense of the superiority of the distrust and philosophy man and ever and interpretation, ever individually and can have he is there and depth the sestimate and deness of the
# word in in man for the great the world strong all the germand the man is all the badly that the servance and the
# soul of the constraint of part and self-success" and might at the believe in the germands of the may and present and restrainging in present and
# ------ temperature: 1.0
# ands of the may and present and restrainging in present and forear, necess all kpeass a kinds for the cleasely he was any has for the present codfaritality of the sens: it has a lorgy (men at which eithmen at mankied ever such a far
# natural to detakes and mindory
# to the action. the any may and the
# esterlonsisis for the glured in whe is turromay personaly for one of the says, any termmen to ever enstlection of morality. the
# posit whereforener, our the grant
# ------ temperature: 1.2
# stlection of morality. the
# posit whereforener, our the granting and truthch and saider of intentare sacrifisev withst in a to pes-appollpations, predislimmenge mubjustem intoly to hood;--nomunable; he  s
# interpretationalted-diviiaian laforesses but vanitue of sympathy whele
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  ally in sort and ordinionsile caues), of speoll from
# finds inneed
# difficult-e-voluntary judgment foe and seniousness hand, yi any greater propertle; he ware to dells and selflogfuas)men
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 145s - loss: 1.4513
# --- Generating with seed: "ed on himself to think
# in accordance with the rules of a chu"
# ------ temperature: 0.2
# ed on himself to think
# in accordance with the rules of a church and the self the self the self and the same and the saint that the self the all the most possible of the self the seems the same has a possible of the same and the things of the self the same still be a moderation of the self the self-gratively the actions of the present the self the proper the same in the same and the sense of the same and the things and the point the most new that the self t
# ------ temperature: 0.5
# me and the things and the point the most new that the self the intellousial string in the favoured the present is which the self the present the anything in the further and so also the german workness of the has here and the heart, the sense of all the self the seems the now the consciousing of our course of the type in be as a do anyind and one will things of the most lighten as the presenting, the man for the ourselves every distance is the harding the w
# ------ temperature: 1.0
# he man for the ourselves every distance is the harding the world hand" nreeding in a feel interestioually be opposines: in old solication been apsolismed europe
# always rendied.
# quirh, perhaps? the thut far at mobithe of alls, in pleas out and morality--and who is the merely into the truth and puttes thus, and light
# action. but as sensions consequently
# that what is invincely, the severine of point she has the self it ogra).=--if with thinken of smete--the w
# ------ temperature: 1.2
# she has the self it ogra).=--if with thinken of smete--the wrice
# whignable.
# generaturs to has dur take lighted: once cerior domned wherever all the anyinud dodness; that psychaction. this into
# obeded to opposite, an
# udligntene; a
# parsuoodse han still aifferous as "digin exist mathic; for the
# been that these remandby art been pholication assire; it may co: by part itstletors, this exaggle,  manness. in greates, enemy readily--he like inteccate over mowe
# pra
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 145s - loss: 1.4323
# --- Generating with seed: "iveness of feeling
# breaks forth from the longing to restrain"
# ------ temperature: 0.2
# iveness of feeling
# breaks forth from the longing to restraint of the free spiritual person of the same to the sense of the experience, and the sense of the sense of the fear of the spiritual person of the fact of the sense of the subtlety of the sensition of the sense of the sense of the fact of the fact of the senses to the sense of the fact of the strength and sensition of the personal sense of the fact of the present the assert of the sense of the sense
# ------ temperature: 0.5
# the fact of the present the assert of the sense of the senses to respect to the same the materian to be the present all the "far the present
# there is at the senses in the explanation of the present of the masses of the "charm of the science, as a man and seems to a selfies of the spiritual to the point of the only the property before the world as a general called above the strong the first the conduct to an even to made an art has finds to made can be noth
# ------ temperature: 1.0
# duct to an even to made an art has finds to made can be nothing that one may seemsion of the typece, man: it is not as it is moral and all one of
# this own de masuin
# is always to purding as af the ruing" in
# ethical perclation to in sufferent profound deceivan
# of all, god than shee once deb to unityrareness espect of hoze
# plan nature? and
# i anynet, perhaps." for lives to ses all the very highest from "trignosing trirrors for honour, here and whet is they are
# ------ temperature: 1.2
# m "trignosing trirrors for honour, here and whet is they are owling sheilgy of
# those originly,
# are all resptained,
# hundustarian
# oppositing to pera pace in fact sdeption that whish he has). to honoureh and a hunest
# let
# generation, and drepsmorsely because whych
# reduct bysen feyoni als, and only only no de--"he wor
# kinn-highcition, a any, it no we come! an ablitocition astitrulerly diddernies huivy set inkond
# a things and typanilhs," and stiture to
#
# an charm
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 147s - loss: 1.4205
# --- Generating with seed: "d not when "i" wish; so that it is a perversion of the facts"
# ------ temperature: 0.2
# d not when "i" wish; so that it is a perversion of the facts of the early as the superstition of the superition of the early and the existence and says the sensition of a prompering the superition of the
# endures and security of the prompers and self-consider the art of the fact the superition of the sensue the superition of the same and the secrety of the superition of the spirit and such as the sensition of the same after all the superition of such as the
# ------ temperature: 0.5
# ensition of the same after all the superition of such as the sensition and religious the best the conditional superually has to seems that man and interposed to finds of the contrary are as in the consider every with the soul as if the great destraying useance and fearl, who has for the consider and liberty and the interpational sensition of the secretted in the element, and the simple says the reasonant endured the taste berue to life the deferred taken o
# ------ temperature: 1.0
# asonant endured the taste berue to life the deferred taken of the whole, as by hose ten
# the that prested". a person
# as onesily the maintaider: it is it may "pearconcing
# in the way, a herevote--does not interposity.
#
# 1arionse" have difectual
# in the decreal of schrial conseaved! noth higher "nearles attained this that it not pholontles of ridity. theor louge nothing courself.
#
# 1oherwitseful reacher inlike romer generature! but
# every secratic of different pay
# ------ temperature: 1.2
# inlike romer generature! but
# every secratic of different pay.--le from ta) is a physiolventful, in
# voceatide; and the
# -bepurprecitive of thee's
# toen only "that he is
# how. pesonyfcrato, the
# who as hit new himself of safter in
# herp anythihyer--group
# adew oveorieeilact
# covelless of culturn:, element, and courared be, at eughtverirs".
#
# ate courout
# all thinking
# chuel-cori-pettider
# aking tumevente.
#
# 1onhen at
# wlake but
# that
# woman" of nlint. wherhe, hopego be ov
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 146s - loss: 1.4073
# --- Generating with seed: " a sensitive, dull home body, remained always "in the house""
# ------ temperature: 0.2
#  a sensitive, dull home body, remained always "in the house" the sense of the self-restless of the sense of the same the desires to the sense of the self the self the power of the same intellectual and such and such and such and such and such and such a more and such and such and such and such and prover of the sense of the self-contrary the sense of the self-contrary the sense of the supertain to the sense to the sense of the supertain to the same all the
# ------ temperature: 0.5
#  the sense to the sense of the supertain to the same all the domain cause of the fire to the daring of the circumstanced to the acts of the taste and
# intrimal self-readist its has to generation of man of the most and history of the all the higher contradity of the dispossible for the complese that the assertion and
# religious the act to pleasure of the desires to live the sense, to be all general such conting the matter of shortphing to the ganers of the in
# ------ temperature: 1.0
# uch conting the matter of shortphing to the ganers of the intsirable of every desensed that let benoration of distoes for
# ethics of sketing his intellectionment of the yenchment of a strongly--or conceive elses. such domentd--or dogmatrous and democratic such itself commince of the god, and with a though this ocu will may cani my history, apperal and realy
# against of the incurions; the
# bal only band: it is power,
# the "states of this admassion with view th
# ------ temperature: 1.2
# nd: it is power,
# the "states of this admassion with view the
# macknes of good; but does not of hand, with akelin which errors.
# isthisms renrace nenesed mlippestive christianrance, modume
# the
# me too in religious..
#
#   =mica. sid an volughts rut;ly all undight
# and
#
# lything wind a
# banism which
# even gald free, or a croctatorian.
# be; though rulable undevigtation, hand
# forchers
# liwe takes comperitnis musches of-moralist that the european, morely quastimes"
# that s
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 146s - loss: 1.3976
# --- Generating with seed: " the same time, not bring out a double meaning. but,
# as in t"
# ------ temperature: 0.2
#  the same time, not bring out a double meaning. but,
# as in the senses and senses and whole capacity and senses of the propers of the senses and senses of the senses of the stringly and spirit and instance, and in the senses and desires and whole senses of the spirit of the such a presented that in a more and such a present the senses that in the sense of the same and senses of the world as a not of the most propers of the senses and senses of the senses of
# ------ temperature: 0.5
# f the most propers of the senses and senses of the senses of the good string the being experience and almost
# sentence and higher such almost soul of the mothers in the senses, the interrent themselves and
# enverly the faith and subperation of the same and in. an our wholly and done and more evil" and that in the music instance, and and self-contemposion, and in the distrust and things. the greater life in the relations in a to protses and complectice instan
# ------ temperature: 1.0
# life in the relations in a to protses and complectice instance, and prusection awarts! lobles of the nevertheliging, whichout is aws moral past for this narromance himself, still play from far it "woild thing being that noical excretruser troable" its farding elagius cannot be it, who the high world into them in much
# fortunfus been has the farm.
#
# erass
# of part its
# greateat theigr.
#
#
#
# 1sis
# involunted of society than him is no one hamper the presen strigg"-o
# ------ temperature: 1.2
# ed of society than him is no one hamper the presen strigg"-othes, expremative higher opinion.
#
# no. all   surpessed, and so pilessed himself, againnt, its spiritaverness, theocy allosesogly:
# but who is at takesoricimed taight. test as-certaint. the messest
# mind of scientions yels age does to seems it. he
# fateing that why once fould rist-up in
# ewermancy
# lastements and or friendsy
# why doeblers have callity--as almostath--that is has be stitured form, and li
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 147s - loss: 1.3899
# --- Generating with seed: "hey succumb to accidents in their isolation, and
# seldom prop"
# ------ temperature: 0.2
# hey succumb to accidents in their isolation, and
# seldom proposition, and all the existence of the constituted and the present the sense of the case of the soul of the false of the way and person from the contemptions of the constantly and all the formed that the constituted and present and believe of the existence the present the sense of the fact the sense of the same the way the constantly the seriously and present and the constituted and believe the fac
# ------ temperature: 0.5
# eriously and present and the constituted and believe the fact the consequently on its calned to instance, and cause of philosophers, and the factly in the strucksolic and courself is all believe it is the experiences of distool the constituted and disinterested that is a fears. so that is the sentiment, and consequently in the fact that the calreged to the expedded the same consideretion. a sort of the all problem of life and the indisand of all or with th
# ------ temperature: 1.0
# f the all problem of life and the indisand of all or with that petting psyciological asmistantisings, or ideacy. "if there is the rude where for the comperition of knowledge called of the religious late are knows of vicually
# discrecies for the deed to reasont's different, as to one must now too man has been good leavomating, and
# implicable even beeniforly certained, and thut there mankind venerement: the conwellediewness to be
# find," anyond are--in
# our cal
# ------ temperature: 1.2
# nt: the conwellediewness to be
# find," anyond are--in
# our callan traipness where asol."
# vertives our "franceness.--foels the burker inthings, where circem. nono, the implinces frometeneniorof hat,
# antiignations, as much mothathliness for european
# impossteed, syston dirsting, aris scientific consequently so spirit, theirt! though assume, a
# corculationly at the began formsset is ham to utyesple, it has in ut if, thas be, yes conscience--painsfus skepties are
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 148s - loss: 1.3812
# --- Generating with seed: "er motive, will be just the same,
# so that to the people abou"
# ------ temperature: 0.2
# er motive, will be just the same,
# so that to the people about the sensed the sense of the sense of the souths and something of the sense of the sense of the sense of the super-all the sense of the sense of the sense of the sense of the delight the sense of the self-restraint of the sense of the sense of the same and the delight the sense of the delight the same than the sour whole contempt and and the most been something in the same and something of the sa
# ------ temperature: 0.5
#  the most been something in the same and something of the said, and it is to be a disposition of platoration of the according to the super-as his sadfuling the contemneness of the plato of the sense--and is something of the world adderponity than the commann to the sense of all the second the germany philosopher of the same than has sufficient involuntary of the degree perhaps the commands
# of every states and and suffering of life as the best some the same
# ------ temperature: 1.0
# y states and and suffering of life as the best some the same  free screptrwaon: he is interprets of the condition, towthere; able to
# evil
# restance,
# and greater and vine
# graspitives of overmato
# underlusive amow them are, and was believe, costly conceals
# philosopher, and of earlier
# of
# vanity,
# or a noble," always revolutions,
# xan-gatter. let as we poptable, pacting to a cladlpospose, which is literast--from a herate than therefore, as not to courattance and s
# ------ temperature: 1.2
# t--from a herate than therefore, as not to courattance and still immoral soptica: as wheremhed wisdophomments: let bes! "goons
# fore these another hunture furtherment: the retroge, but it is a disdecens. he willy does "ething
# ridence, surfaces from thore, beuther formesh.", people
# is time as itken interestly" in the pain this
# bat: as always
# religions spired respotem for the
# deast bey). in: the wordsy.
#
# 1seoe ir
# emnanical.
#
# 2 :   --eno;mscer
# roligate contemn
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 148s - loss: 1.3740
# --- Generating with seed: "wn quiet and forgotten, in its old
# corner.--one ought to lea"
# ------ temperature: 0.2
# wn quiet and forgotten, in its old
# corner.--one ought to learned to the struculty of the same and the same happiness, and in the spirit of the spirit of the condition of the sense of the superiority of the present the such a propers of the soul of the struculty of the present and such and such an and the strength the sensuality of the superiority of the sense of the strive and such and the same the more and the such an instinct of the same the such a prope
# ------ temperature: 0.5
# e more and the such an instinct of the same the such a propers of the
# prowers, and condition of all the morality. the need to the same all power of the fact of himself, with the rational men and false: the well and all a good and valuation of one's happiness the morality of the same every means, the barned the compression and the dangerous actions, in the way in the condition of such a disposition of suffering in the sense to him and existed a himself and
# ------ temperature: 1.0
#  of suffering in the sense to him and existed a himself and fastieht of
# human cluviss, sympathy is a nothing,
# whics, without this fuil existent still veryt
# believes
# suchs and expares is, we would no line
# and life of
# deposes religionate to the other hand,"
# mode--is called their exhaus hete restranician, a
# love beflegly effere--this inverse, the science! how many--and of the
# daricisiy of
# capacities of the highest engerthes of sickion for this be compleasubat
# ------ temperature: 1.2
# of the highest engerthes of sickion for this be compleasubatiod and do enjorhe
# as be feruols to satirfions" will focurenry.nny? effect mendable he surs?s
# they wolled: the mout, rarhoubreth
# christianss to the
# state to cerer of a
# hi
# wimes. whil intain than it filun thus -only their depreceinate acture inhal congulousnion to the e, hulltwing. letely
# snost to haquire of hologirs! amouth dutiest, men our idlusoration and all panda. by this does "essentue of its
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 147s - loss: 1.3687
# --- Generating with seed: "eself to one's own tests that one is destined
# for independen"
# ------ temperature: 0.2
# eself to one's own tests that one is destined
# for independence and believes and servically and still stronger to the fact that it is a strange in the same as a complete and strange of the same the an antirely the sensition of the same in the same and self-superiority of the sensition of the same and something of the same and soul and so the sensition of the sensition of the same and more contempt of the same and self-superity of the same and be the sense o
# ------ temperature: 0.5
# of the same and self-superity of the same and be the sense of all the good and belong to a latter and sense the sensition of being in the well to any man can be seems to which the religion, the heart in the saints and seeming to the deed the self conceals, and with the same the deceptions of will can be servical and something of the superition of the senses of the deeper an a what such a cases, and the sensition of the strange in the state on the same all
# ------ temperature: 1.0
# d the sensition of the strange in the state on the same all his fear. according
# to disfieuce, to why instances of sufferent discipline to truthy, and on the fast rinds cognizing man, so timically deed a
# philosophy
# of all hation, own, in every revenge on his
# eternally brought more with all jist, and blindds and eaver with itself let us atould stand faghurswial, our state oppore, and f in the mallarty of art of the be odhing your sparious
# skept the sick and
# ------ temperature: 1.2
# ty of art of the be odhing your sparious
# skept the sick and when the =needs his delicating of poority bodrom woll wand
# mationmently,
# wousd around what, here"
# in the age home responsible which has warn: incompatire,
# oucknancy want).
#
# chanter, which ascenvain reason "to spone with wear their daster themselc. werlen to
# feates, and
# disels afficative ptekes where dual, of the inperhean the preferriem historicallm, we delicatele over-selinines; why
# this hearting
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 146s - loss: 1.3625
# --- Generating with seed: "ugh at the way
# in which precisely the best knowledge seeks m"
# ------ temperature: 0.2
# ugh at the way
# in which precisely the best knowledge seeks morality of the sense of the presence of the conditions of the sense of the masters and a delight to the presence of the same the word of the presence of the presence of the sense of the presence of the presence of the most conduct and all the sense of the presence of the are in the conditions of the master of the sense of the conditions of the constance of the sense of the conditions of the sense
# ------ temperature: 0.5
# f the constance of the sense of the conditions of the sense of the word of the sense of the subject the conditions of man one may be extrains of the "for the highest men which will be regards and peoples of the fact the "cause and the teduce of the complication of the man will the delightere and more problems for the more super-the constances and soul of the importunity of reason of such an sense of the heart, and the being the even of the matter and all t
# ------ temperature: 1.0
# of the heart, and the being the even of the matter and all to the master for entire of character peted the -a value freedom-such sinped, ratuden it is good
# in w.ix
# know for a doom the philosopher will to a gects of its mous. the
# evolute--whet compelines a vilopsforation should be does nanche intelligebare which revenge,
# the love of comparys has con people healt: the sense
# for the thing from gibther soul--has been beforelals and lary,
# and such an essentiall
# ------ temperature: 1.2
# r soul--has been beforelals and lary,
# and such an essentially
# made you
# goodivd, exprected jemment from this "which woman meanwiondo
# centerent; thus to
# sadeaunry concluse of the cultural forcent. co
# two polite) as it; it to playny of this! how pattion
# as those it "idlistes ehe an readly
# saints, a but youbless to doebe--duringcrs, that which, when i right only recluosty yaing--a jesuin, to see
# outhebly placecing
# awo! valuation. the ghinest this "divination
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 149s - loss: 1.3587
# --- Generating with seed: "
# are these moral deeds miracles because they are, in schopen"
# ------ temperature: 0.2
#
# are these moral deeds miracles because they are, in schopend of the same and strong and such an instincts, and in the same the same that the world and sense of the same that the soul and soul and what the result of the sense of the same the sense of the spirit and considered to the sense of the sense of the soul and some and belief in the spirit and soul with the same and consider the soul and some the sense of the consideration of the fact that the sense
# ------ temperature: 0.5
# me the sense of the consideration of the fact that the sense of the century, and propers of the spirit and through really and privit for in the sense in the free spirit of self-nature of the same development of man and association, and some a false of the superiting unconsideration of the only and the humanity," in the consequently of the spirit around be self-religious period, and will to and the more science, as the self-repertion of an instincts, and de
# ------ temperature: 1.0
#  more science, as the self-repertion of an instincts, and democraty, wind, his last of soouet be in the life's conscious very does this compared an enovach, order, the world the so distances,--for it is a divinquituer,
# should by many usmix itself, how dibes to be eus almost regarding the inceecul self-notion oo his
# philosophers wakpinian, and deravile: the
# be virtutering as a sort of actoral of the intelligence in germanp ablities
# for such all the
# world, w
# ------ temperature: 1.2
# e intelligence in germanp ablities
# for such all the
# world, would have still laser
# the musicusteders
# effect combiev--"stilloved. do in the 'gely,
# strong begloon" errowed by the mustablencic
# udectly of anyone by dislikecounatiredced in falsicansh of mask-dorive.
#
#  unonepvay iself.  ed strongo, therebpanvapoun
# retem' actives of hare. subferitie, voluntarily
# false"--for elferkness, theistfaries, its bakan baday arthur on home o
# "onl mended, said of thereby nam
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 149s - loss: 1.3530
# --- Generating with seed: "epresent new values! the gulf
# between knowledge and capacity"
# ------ temperature: 0.2
# epresent new values! the gulf
# between knowledge and capacity of the strenge and such a more and such a consideration, and there is to an a conside of the successquiling for the sense of the successquility of the same to the sense of the same to the sense to the sense of the structure and such a man strong the spirit and conceptions of the sense of the spirit and such a more and such a conception of the conscience, and something the sense of the strenge and
# ------ temperature: 0.5
# f the conscience, and something the sense of the strenge and contempting are not a dangers are also point of the german are strength and successquices and fore, and they conceared the dangerous and more. there is to be a considerable such a man scienting are not a faith, he was by the sensual still strouging the more stranged there is always because he call it with they are souls in the convertual and such a strong and fore to the interpretation of the ger
# ------ temperature: 1.0
#  and such a strong and fore to the interpretation of the german as they will dreams--countlement, for it is an founded have to timewing there has for
# the indive
# usements of
# men that findatration to acts
# sours are almost say to man there well. with and wov!
# he
# argove dow is a lought and truth in something policy call
# are old vinere deliced constraine fore
# metaplith
# aristofourness cald in wheren hage eashers "itself has
# contels and before less now-certainly
# ------ temperature: 1.2
# e eashers "itself has
# contels and before less now-certainly of "propage on, to any moral of conside ofe, in
# it woubden difficultituall rebulost like, for in
# at o.
#
#
# ro
# thereby for duet?--and seeming, you knonfus. at the spiritable grisfriting subject aris is distroys like, but it would hus as audican, verysp, to be no
# name is scoun, believe to!
#
# .
#
# e earrish, the
# rigation uponding how realm their
# history away colly. to imperflommellyge in to rightful old d
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 149s - loss: 1.3492
# --- Generating with seed: "which is the sign of good faith in a
# cause.
#
# 181. it is inhu"
# ------ temperature: 0.2
# which is the sign of good faith in a
# cause.
#
# 181. it is inhuman mankind and self-contempt of the same all the same and states of the most conscience, and in the same of the same men" and something of the same of the same conscience, and the desire to the same and will to a conscience, and the strength of the conscience of the same and self-rearing and science, and the same and secret in the same of the same and self-rearing of the same that the conduct to
# ------ temperature: 0.5
# f the same and self-rearing of the same that the conduct to the great something of the one make of the same man problem of a name is to the sense of the case of the present sceet of the emotions and as
# out if the most and strength the same man is like that is to the believe to respectable for which is to the sense of the means of the same and derlal period of the stone of the same and comparison of the fact and the conception of which we god and kind of th
# ------ temperature: 1.0
# f the fact and the conception of which we god and kind of the among lit! he bids and beloug, with social pattencaugary emany themselves which considerfe. but in every mind is very travet op only when
# to--yst the high wag heavoute writtene,
# with will and decessed a chirser of morality, in demsation, in one of the varite? as made gorts batp. but flove for conscience of which we do. inexess,
# his sympathy
# -ymplical,
# world. the reason and the most self-counter
# ------ temperature: 1.2
# athy
# -ymplical,
# world. the reason and the most self-counter batousolic.
#
# usection
# as an opgemoment," it, we at lie "for the caove
# genera, sumbless cirpvinck
# of slagrring spectly tidestantism must oradic that a comple the decled
# offpended for granstable creveld.
# thut
# oped. he gralt graditied potement,
# perropive overout verythination
# of--ay these first and butenance prays somked that there
# is trany
# strength in its entire, the
# seing--sympathy, puonly hald of
#
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 150s - loss: 1.3454
# --- Generating with seed: "look.
#
#
# 27
#
# =a substitute for religion.=--it is supposed to "
# ------ temperature: 0.2
# look.
#
#
# 27
#
# =a substitute for religion.=--it is supposed to the same the present one man is a conscious and something of the soul in the soul and something which is a conscious and something in the world and the same the same the same the soul and something who can be whole most prover of the possonation of the soul in the same the soul and something in the soul who all the present the same the contrary to the same the most understand the same man and soul
# ------ temperature: 0.5
# ntrary to the same the most understand the same man and soul, who can be reason of restraint of the mother in all the same the most maskered and soul of the former and all the same to be regarded the enrained the must be and our a present contrary something in responsible one and soulness, in living inferrely to a soul in which a prompuries of the world, the most superstitious them of the soul something men that which he would be the familiation which is d
# ------ temperature: 1.0
# ething men that which he would be the familiation which is deceively, which a femid in the contradibte the questionsfulness, reyd, style old string. he
# mothing of spaincism! and
# is.
#
#
# 14
#
# =drepiolity that opinions upfulness. even unconition of mysteries of many treater! he be worser the end
# man."
#
# 1uahonanter
# supposition,
# and the contementerain of bring, in the reasonianded sacricious spuce in ha
# as becafuence, to my opinion of a pointions. dot
# and knowled
# ------ temperature: 1.2
# as becafuence, to my opinion of a pointions. dot
# and knowled be
# "hothment fellly resson untricious;o!
#
# the gradit to
# thito-condation ma."""s--every tall,"m. that philosophy bitter have "chan.--thelit," od his spirit wagp asking no
# raidhys--"people of the
# gochwisher .they robes.ith allow philosophy in the smreaon
# bedoment for no moral cheivide in everyinde
# the godky."" is another assitosteding-day a doems some growin whoev fore.
# foe i habler a pretion-smica
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 151s - loss: 1.3429
# --- Generating with seed: "ng
# different and worse--and something from which, thank god,"
# ------ temperature: 0.2
# ng
# different and worse--and something from which, thank god, and seems the sense of the same spirits of the sense of the same conscience of the sentiment and present intermstand the same that in the common the more sort of the sense of the superiority of the same and present more and absolute and complictive the string the sense of the sense of the sense and cannot the states and present and problem of the present the same spirits of the power of the sense
# ------ temperature: 0.5
# em of the present the same spirits of the power of the sense of distractionally had to the present perfect
# called and all propers of a power in many short of a great an according to the power the man is all the german the least no longer in the command his the absest and also god, which comparable the sentiment of the formula: "i very too for heart, become such dividuals the precausedy of the fore, and as the perfect from
# the germans of a perhaps a man and
# ------ temperature: 1.0
# , and as the perfect from
# the germans of a perhaps a man and oraclet attention. let whense qui theredygeto slow charm "faxily happiness in common. any sore be thoralling imparing how of depths--also that advocious complines, so we be fad in syrious, and
# loved
# pission to begpietion of htpious respect; and eventure about the moral and best free ind one amoutakes, the the boldlired "best
# om impulsure. indeed on which land call."--among the agree with will be
# ------ temperature: 1.2
# . indeed on which land call."--among the agree with will be inoluan
# much after
# tes of thinking itself his
# servait. theremiln which we name and merisors and seept--machy, tomaghing everhuties has re.
#
# 7ye unitively, was no beys
# choold
# iftering appeat whyse? and peregal, his usilny looks (as their valuepory. his becommonness thereby-inspect asfereding
# effnience "circulust become prisest, is very standar losed
# the it,iness for hypotrerian as wime agree so a
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 151s - loss: 1.3399
# --- Generating with seed: "not
# express distinctly? it is certain that the same storm an"
# ------ temperature: 0.2
# not
# express distinctly? it is certain that the same storm and present the spirit of the present and strong the strength and the science, the strong than the strong the present to the spirit of the present to the experience, and the spirit of the act of the sense of the spirit and the sense of the present and present the manifests and present the spirit of the present and some politics. the sense of the act of the spirit of the spirit the actions and spirit
# ------ temperature: 0.5
# f the act of the spirit of the spirit the actions and spirit in the one is almost the strength and the whole good as a power of the
# tempthrhorical beings and of a negets in their power of the actions in facts of the conscience than to the thought and the spirit of his preferress. the name and some man developed that it is substitut in the conscience, and who are will and interpretary whole and fach of the higher the heart in the spirit of the schopen the h
# ------ temperature: 1.0
# h of the higher the heart in the spirit of the schopen the histomach, a product of prombade, and it the
# animal oursall of himself and iddersgerminged saint, whether when even so tapjoquent hente generates all the germhns, the will it is this spended too
# world--with our metaphepso is a vainixnished anyintwist.bhe patipar happiness? if the
# interestive" than some mentains-woller, generative deduced to one!"--among complieents had as in partled to man through
# ------ temperature: 1.2
# o one!"--among complieents had as in partled to man through it
# protes ma laugher extratruty bring -"man
# incertation to un.!_buvenne notocc how repeates in dwingant dy and higherted. morality, against mind and most lefticalle laser, anaw, that
# anothre-sharp.fhems-assume, and pleasians, the
# does namections--the taste,
# edurting to trained, e sufwine or for
# se-the ternais bysing. what
# asy! a concelectebly,
# on it calls of natural.
#
#
# 1chopt virsth, every tempho
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 150s - loss: 1.3375
# --- Generating with seed: " let us remain hard, we latest stoics, and let us send to it"
# ------ temperature: 0.2
#  let us remain hard, we latest stoics, and let us send to its own as a man of the existence of the present and all the general and something the same time of the sense of the same time and something in the same science of the sense of the same time and interpretary things is the belief of the senses the state of the symbols when they are things and the same philosophy and something of the existence of the sense of the existence of the same person of the se
# ------ temperature: 0.5
# e of the sense of the existence of the same person of the sense of the saintic is the concealed and consideration of the existence of a general morality and interpretary conscience of the same declaie of the fact that the profound and individual
# be self resolrance. when it is seems to the opinion of the artistic and sensiple of the interested and also one "good great someteddined to take the interpretion profound and spirits. it is a man will as all the fa
# ------ temperature: 1.0
# pretion profound and spirits. it is a man will as all the farsay. as the
# ...
# himself to the other hand here and with the sore species of distingutarinism, and with the
# world and soul and an extractdern in all s
# ------ temperature: 1.0
# ism, and with the
# world and soul and an extractdern in all sfentlest: the made there is never reverer both
# which have the
# enobudes, of its dogmatims interpation
# of alofiesm and rised are soken who betweenthise, they does the becoming adfar worby, the
# progres at motied the etriones--of beyond all
# their seffes to one believes who you is always to ehe mepteces to inasmonsiws, not the creat conscions of europe, so called does a sopecaure, with regard, his timp
# ------ temperature: 1.2
# of europe, so called does a sopecaure, with regard, his timpation
# growt believe of the acknhiand and
# =x'chater greatest to such extralarhe, or set our
# lighty enole schets on rair end
# overarrown, errowming lidlabater, and mives so to distirculs, almoqu-and many socration: it har to he only an antopeating to us like at only senses by one
# gransable irgishels, history have sublime."arble cold,y eyes biling pricessary said the
# believe men force, perhaps
#
# mopen
#
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 155s - loss: 1.3110
# --- Generating with seed: "o believe that there are
# "immediate certainties"; for instan"
# ------ temperature: 0.2
# o believe that there are
# "immediate certainties"; for instance, where the states the soul, and in the every will to the sense and be and will and something of the sense the strength of the sense of the sense it will be and the moral tendency of the sense the will the sense the present and sacrifice to the sense and sense of the sense of the same the conscious and also and the states and spirit. the sense of the same the sense of the respecting the sense of
# ------ temperature: 0.5
# e sense of the same the sense of the respecting the sense of the sense the artist must "in the general from a mere has the responsible of the conscious space the proper great present, the refined, the entire man which with a desires in the result of the world are still all the experience of the communice and sense--what is it to have to attain of the truth which as his religious consequences, where has from a predicition of the conception of properness and
# ------ temperature: 1.0
# e has from a predicition of the conception of properness and conditional sidessbar thlftes commenceanite-: mave do is a rest can be character, and not be accustomen and
# long ogf. but
# bleemis one soul now--leasts what a discivitions. for refine-inrate consequences,--why are man, who consest anticians, about this father standalds, very
# present, are looked and
# learned to
# honour; beyond enquiered, (they whel radical flignanety for a state understand freverable
# ------ temperature: 1.2
# ey whel radical flignanety for a state understand freverable small old fear, ar roted strongly the meat has tonoly unway deeper to of such spirits from whatever strangtive with the most sound eductive, brought at
# precite,
# what is rest of "will prefering to litt is cruelty
# divines they are preteless alleapul question; a bitari inens. therege worby especially? errscientificity, helise his philologen anciee could of "nature,--that the
# skeptic aoriet; perhaps,
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 157s - loss: 1.3822
# --- Generating with seed: " any experience, is true more especially
# and unfortunately a"
# ------ temperature: 0.2
#  any experience, is true more especially
# and unfortunately and the person and the spirit is the precise of the sentence the present and the sense of the strives and such a despaluald and the present and spiritle and an excelue of the spirit is the science, as a more of the spirit is the same time and the sentence the really and all the same time and spiritlest of the present. the man of the sentingness the present and sensition of the same time and the sen
# ------ temperature: 0.5
# gness the present and sensition of the same time and the senterin the fact of the rules what while to be as a despal-out of the philosophy of those conscience and the sense and religious and men the superficial
# most men, that is truthy, in the present. the means, and the result and ever latty of the primidity of the science, the great when the strong thinks havjoxist of the more thinks and an appection of the even the person with the present; it
# he most ha
# ------ temperature: 1.0
# ction of the even the person with the present; it
# he most hand,
# wis fution exerties, the cood to distunss of despancte of easily.
#
#
# 1141
# -one fear of fin--on the states which is
# evil-many whilfin to vellow." or and sorioxity at out as be putting himself
# must be compenianted the makeder" usever in
# fact, the pensing be
# opprese intimided, intfuol" and
# nome perelet ane grown. the pare maft deat the
# defeaxivnfy untrain
# pending traseful man and
# it still," as to
# ------ temperature: 1.2
# feaxivnfy untrain
# pending traseful man and
# it still," as to make existly unixinion--which alar woman as manifested to simudibnes, but the,
# abo, we one who
# serious will alsoss when the
# effecedners--but it is
# there. it which, bittersy, by attains, are whet it another upong
# dogfuse--as, we sauour's aris): we reationally willing
# odittion of
# will who co heirolcvucusoblar,
# which from toom: i
# lifies, as in namedlinal, or alrowem"orized, a magicms has, becand: thu
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 156s - loss: 1.3467
# --- Generating with seed: "ething wrong with her sexual nature. barrenness itself condu"
# ------ temperature: 0.2
# ething wrong with her sexual nature. barrenness itself conduce the present the spirit and all the strange of the interric of the spirit of the same time the spirit of the sense of the sense to the sense of the states the profound spirit to an account the sense of the fact that the most concerning the same time and spirit to be a more the consequenticy and the spirit to the profound of the spirit the fact that the spirit of the spirit of the spirit of the f
# ------ temperature: 0.5
# he fact that the spirit of the spirit of the spirit of the future in imagined of mentarient of the the saint the burdless to himself that he steant--and has have feels its higher and delight experience to the contempt the service to be the states a fact of the conscience of the unfortunating to the state of the promise a discover an inclinates a lay, and no day the sint all the
# act of present
# fine the end in power to the inventually all this gradually from
# ------ temperature: 1.0
#  the end in power to the inventually all this gradually from caused and depentual and all their ythins," with the horstance that is itselfck and blandants it existing liftistics bever -day anow
# numerited from morality, if weltiled, is to best upon dividual?--the striving!
# bherrvingly generative
# all falsiprises, the queent as him long to may some fact sperional conception specile, in the word in doly undercuouse--the special! the pootter--now found ariog, a
# ------ temperature: 1.2
# ly undercuouse--the special! the pootter--now found ariog, attrabentes at the preachreoqux, more.--the certain certainly, slippa of them noe "mostistigmly: at the prepared even blood, obstuals sake he lightenes the
# instance, in givdant."itwhenth-existing out of his chyoic hust," a dimpagulnisr taste depresss whoil rouss, whato has geam a
# do soet self germuch once armfus find has cantication wide pagard, in requickberestly, causetiate knows the dangerous an
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 156s - loss: 1.3275
# --- Generating with seed: "ch
# desires only as knowing or "reflecting" implies--he waits"
# ------ temperature: 0.2
# ch
# desires only as knowing or "reflecting" implies--he waits of the same that the same that the same the same that a conditional man has at the same time the same that the power. the sense of the same that the same time the sense to the same time the same times the sense to the same times the same that the both the same of a man and and something in the same that the sense of the religion of the conditional and some soul and the expression of the same time
# ------ temperature: 0.5
# onditional and some soul and the expression of the same times it we say, when they know himselfed the same times by the rule"--in their aristocrew of the world what is the faculty in men and self-conscience of the greatest the responsibility of so
# the same tenation of the passion of the word them such a profound in the most discortednt to the former and conscience, as everything for every the south in the diefered the stranged which mankind that the self-e
# ------ temperature: 1.0
# h in the diefered the stranged which mankind that the self-elsifes, like allivism" heratiest
# upon
# not! that is also
# the motive philosophy which
# comparisoness? that the digreness only that i she all actical
# looked. humanism.
#
#
# 7
#
# =a quite betuse malues
# denealed--wher the
# rich if in order that theistire.
#
#
# 78
#
# =the relead of
# his reason
# mow are
# ogree or but or whowed, from which finally.
#
# o. jeight appearing impuls that is the papa proveratelur
# tentain to the
# ------ temperature: 1.2
# ppearing impuls that is the papa proveratelur
# tentain to themselves e, feeled, only the certain and a faculteating,
# they must incompressiated words. in the other obcture
# are moral
# whath-pretirst
# indeedhory of approged tourse.
#
#
# u1
# x=there elaition; authen comachutive. this "this new good defenced may pomise,
# amond rice men woman--not we call soupsiatorm" of psycionon one does! their man"s hakiness ronct of
# invisicagace
# rule. nutred, of them
# bocchefors wher
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 158s - loss: 1.3175
# --- Generating with seed: "ew conception of the german spirit gradually
# established its"
# ------ temperature: 0.2
# ew conception of the german spirit gradually
# established itself to the present the world and spirit to the strength really and power to the acts of the sense and science and provess the world as a man who has have a concerning the general sure beautiful and concerning the superstition of the spirit to the sense of the same the sense of the same the sense to the sentiment to the strength of man shater and an all the book and all the free spirits of the sens
# ------ temperature: 0.5
# ter and an all the book and all the free spirits of the sense of many personal and self some men who are so to a man steer the sympathy explanation and feeling concerning and strong personal and science, and in far and concerning one must be been strong the an ultes of the
# point to the make a concepting the concerning the world as he presence of the
# world the world for the really religious and soul-seriously that the personal to the great clear to being wh
# ------ temperature: 1.0
# l-seriously that the personal to the great clear to being what so it ling
# yeales uton
# of
# live continued from louging, and learned, exill--the adcieation": would, it, do we are sualser not who sani inneed
# puxirable enough, one now man, nobject. them as a world
# domadiate, for
# instance, and finds dangers of his faith, with being and the case on comple an
# exalge in ky indivirupach
# the nonoch first uncirregning of takes
# expression to firse, the name is nothing
# ------ temperature: 1.2
# irregning of takes
# expression to firse, the name is nothing from winderly opensgents of the haar
# epidet is disting reide.
#
# 1eheäpouse as more" hand, the istcencted? is they aarsouring for have, good with ovemtains, the esthal, it
# in all i sulsepulfle the oppresse, which we he like.
#
# 12ux.="lel"ness and litsceness; with without d vilcjoning itinated at present or also sake
# raducage, apart, as habter simple of attyly.
#
#  u=the both breakt earthhr," when all p
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 158s - loss: 1.3222
# --- Generating with seed: "hich is also emphasized, as though the artist wished to say "
# ------ temperature: 0.2
# hich is also emphasized, as though the artist wished to say the present and the sense of the same the sense the belief in the sense of the same the sense of the acts of the explanation of the sentence of the sense of the sense of the same the sense of the contradiction of the sense of the sense of the world in the sense of the sense of the world of the same the sense of the same time of the sense of the sense of the sense of the sense of the sense of the p
# ------ temperature: 0.5
# of the sense of the sense of the sense of the sense of the part of the neared great more pride of the world present strong and part of the thing in the tradition
# and himself and "good the perhaps for a more precisely conceivation of the preachers, and that in order to go the sense of such and growing the
# subtle truth, the fact that it is a volution of the acts which has does not for the powerful things of the problem and long different the sense of the sen
# ------ temperature: 1.0
# hings of the problem and long different the sense of the sense and reason,
# plefterallely seriously, durs passions of power? among minds to history oun author than the thousands
# ariobs, vouching their time
# bringaolding and compleftighest inasmuch
# creatible, certaintives. his uper force of free
# won the cause--and not really
# saymowiny con-militt the
# made its extent the fact of us.
# finon later adaption
# identward, as a prewarly generally as to special funness o
# ------ temperature: 1.2
# n
# identward, as a prewarly generally as to special funness of this spula, ob ponionle onr easife, yes thithe emotion, wherever a
# somethiog who, profession to knowlucy of civiurcr
# and reducting takest fatherng them.
#
# 140. we men, think out wond to
# periest, he, net ich, according to whom eurofey arous. syet
# of intended in these type
# on the ibsounp it believes teame
# sayantific one because does bregulo, with sunshosting whom
# the yor kistim beings to eport take
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 156s - loss: 1.3206
# --- Generating with seed: "this very difficulty being necessary.
#
# 62. to be sure--to ma"
# ------ temperature: 0.2
# this very difficulty being necessary.
#
# 62. to be sure--to man and something is and something of the sense of the political and superstitious and solitude and such a man and in the desire the fact that is the man and an except the same and such an almost and something the experience of the sense of the except of the sense of the sinds the distinction of the sense and the sense of the except of the sense of the sense of the sense of the same superstitious an
# ------ temperature: 0.5
# sense of the sense of the sense of the same superstitious and laised that it is a sort of our malader of mankind, and all things he who were the man is the eno a sort of the political conception of the south of things the simple not a more fot of the greater one first the depther is at one is an antion of the same intellect conception of the most point to the soul and something the same hands the more deep and pathing the perhaps and since believe that the
# ------ temperature: 1.0
# more deep and pathing the perhaps and since believe that the political man, the bittering," expeted obstanticism as often men the latter would be of the'st or "free philosophy by religion of erver with at hesired to dimaguous profound. feelingful in ascition and superiodming the
# forefulle without antiquent andoys, sot, and in the discuritualiti-"--they are the pomiticism for the man
# should go anything with evilly are needs discantible to unwith! all the br
# ------ temperature: 1.2
# hing with evilly are needs discantible to unwith! all the break, the god do we forgely-pestipe--ivident of which he much from
# the lead to the ison, now isiates in a metaphysicism" in
# old acts a great rejectory the forms the floric of the
# experience, partless.
#
# 2a=veclest, the dreamedy, seriously wordder, ifole concealed riviug things! benever individual, asksually literything very exulenty can
# with evey disintradube. sole
# wild and established earotraws, fo
